# %%
 import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
titanic=pd.read_csv("train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Age"]=titanic["Age"].fillna(titanic["Age"].mean())
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic.dropna(inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic=titanic.drop("Name", axis=1)
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 1              2         1       1  female  38.0      1      0  PC 17599
# 3              4         1       1  female  35.0      1      0    113803
# 6              7         0       1    male  54.0      0      0     17463
# 10            11         1       3  female   4.0      1      1   PP 9549
# 11            12         1       1  female  58.0      0      0    113783
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 871          872         1       1  female  47.0      1      1     11751
# 872          873         0       1    male  33.0      0      0       695
# 879          880         1       1  female  56.0      0      1     11767
# 887          888         1       1  female  19.0      0      0    112053
# 889          890         1       1    male  26.0      0      0    111369
#
#         Fare        Cabin Embarked
# 1    71.2833          C85        C
# ...

# %%
gender = pd.read_csv("gender_submission.csv")
gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
X=titanic.drop("Survived", axis=1)
y=titanic["Survived"]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categoricalfeatures = ["Ticket", "Sex", "Cabin","Embarked"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot",one_hot,categoricalfeatures)],remainder="passthrough")
transformed_X= transformer.fit_transform(X)
transformed_X
# Out:
# <202x298 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1754 stored elements in Compressed Sparse Row format>

# %%
pd.DataFrame(transformed_X)
# Out:
#                                                      0
# 0      (0, 123)\t1.0\n  (0, 141)\t1.0\n  (0, 223)\t...
# 1      (0, 36)\t1.0\n  (0, 141)\t1.0\n  (0, 197)\t1...
# 2      (0, 62)\t1.0\n  (0, 142)\t1.0\n  (0, 271)\t1...
# 3      (0, 134)\t1.0\n  (0, 141)\t1.0\n  (0, 287)\t...
# 4      (0, 31)\t1.0\n  (0, 141)\t1.0\n  (0, 191)\t1...
# ..                                                 ...
# 197    (0, 38)\t1.0\n  (0, 141)\t1.0\n  (0, 244)\t1...
# 198    (0, 102)\t1.0\n  (0, 142)\t1.0\n  (0, 176)\t...
# 199    (0, 43)\t1.0\n  (0, 141)\t1.0\n  (0, 212)\t1...
# 200    (0, 10)\t1.0\n  (0, 141)\t1.0\n  (0, 172)\t1...
# 201    (0, 8)\t1.0\n  (0, 142)\t1.0\n  (0, 202)\t1....
#
# [202 rows x 1 columns]

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(transformed_X, y)

#check the score of the model 
clf.score(transformed_X, y)
# Out:
# 1.0

# %%
test_titanic=pd.read_csv("test.csv")
test_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test_titanic["Age"]=test_titanic["Age"].fillna(test_titanic["Age"].mean())
test_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
test_titanic.dropna(inplace=True)
test_titanic
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch         Ticket      Fare  \
# 12           904       1  female  23.0      1      0          21228   82.2667
# 14           906       1  female  47.0      1      0    W.E.P. 5734   61.1750
# 24           916       1  female  48.0      1      3       PC 17608  262.3750
# 26           918       1  female  22.0      0      1         113509   61.9792
# 28           920       1    male  41.0      0      0         113054   30.5000
# ..           ...     ...     ...   ...    ...    ...            ...       ...
# 404         1296       1    male  43.0      1      0          17765   27.7208
# 405         1297       2    male  20.0      0      0  SC/PARIS 2166   13.8625
# 407         1299       1    male  50.0      1      1         113503  211.5000
# 411         1303       1  female  37.0      1      0          19928   90.0000
# 414         1306       1  female  39.0      0      0       PC 17758  108.9000
#
#                Cabin Embarked
# ...

# %%
test_titanic=test_titanic.drop("Name", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 test_titanic=test_titanic.drop("Name", axis=1)
#
# File ~\desktop\mlproject1\env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\desktop\mlproject1\env\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
X_test=test_titanic

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categoricalfeatures = ["Ticket", "Sex", "Cabin","Embarked"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot",one_hot,categoricalfeatures)],remainder="passthrough")
transformedtest_X= transformer.fit_transform(X_test)
transformedtest_X

# %%
y_preds=clf.predict(transformedtest_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 y_preds=clf.predict(transformedtest_X)
#
# File ~\desktop\mlproject1\env\lib\site-packages\sklearn\ensemble\_forest.py:808, in ForestClassifier.predict(self, X)
#     787 def predict(self, X):
#     788     """
#     789     Predict class for X.
#     790
#    (...)
#     806         The predicted classes.
#     807     """
# --> 808     proba = self.predict_proba(X)
#     810     if self.n_outputs_ == 1:
#     811         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\desktop\mlproject1\env\lib\site-packages\sklearn\ensemble\_forest.py:850, in ForestClassifier.predict_proba(self, X)
#     848 check_is_fitted(self)
#     849 # Check data
# --> 850 X = self._validate_X_predict(X)
#     852 # Assign chunk of trees to jobs
# ...
